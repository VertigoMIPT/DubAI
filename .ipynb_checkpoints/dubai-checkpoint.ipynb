# %% [markdown]
# # Making prediction model
# # EDA

# %%
import glob
import os
import pandas as pd
import numpy as np
import scipy, sklearn
from  sklearn.preprocessing import OneHotEncoder as OneHotEncoder
from sklearn.preprocessing import TargetEncoder
from sklearn.metrics import mean_absolute_error, mean_squared_error, root_mean_squared_error, r2_score
from sklearn.metrics import explained_variance_score
from sklearn import preprocessing

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
import xgboost

from  matplotlib import pyplot as plt
from sklearn.preprocessing import normalize

# %%
# We need to make unique ids for each estate 
# and take into account reselling - count how many times estate were met

# %%
#### Categorical features ####

# %%
df = pd.read_csv('/Users/a.evdakimov/Transactions.csv')


#df = df[df['actual_worth'] <= 1000000]


df_ = df[
    ['instance_date',
    'procedure_name_en',
   'property_type_en',
   'property_sub_type_en',
   'property_usage_en',
   'reg_type_en',
   'area_name_en',
   'building_name_en',
   'project_name_en',
   'master_project_en',
   'nearest_landmark_en',
   'nearest_metro_en',
   'nearest_mall_en',
   'rooms_en',
   'has_parking',
   'procedure_area',
    'actual_worth',
    'meter_sale_price']
  ]

df_ = df_.sort_values(by='instance_date')
df_ = df_.dropna()

df_['year'] = df_['instance_date'].apply(lambda x: x[-4:])
df_sell = df_[df_['procedure_name_en'] == 'Sell']


#df_sell = df_sell[df_sell['property_sub_type_en'] == 'Shop']
#df_sell[(df_sell['actual_worth'] <= 1000000) & (df_sell['actual_worth'] >= 100000)]

df_sell_clean = df_sell[
    [
        'property_sub_type_en',
         'property_usage_en', 
         'nearest_landmark_en',
        'nearest_metro_en',
        'nearest_mall_en',
        'rooms_en',
        'has_parking',
        'procedure_area',
        'year',
        'actual_worth',
       'area_name_en',
       'building_name_en',
       'project_name_en',
        
]]

OH_encoder = OneHotEncoder(handle_unknown='ignore',
                           sparse_output = False,
                          dtype = int)

df_sell_clean_ohe = df_sell_clean[
    [
                                 'property_sub_type_en',
                                  'property_usage_en',
                                  'nearest_landmark_en',
                                  'nearest_metro_en',
                                  'nearest_mall_en',
                                  'rooms_en',
                                  'has_parking',
        
                                  'area_name_en',
                                   'building_name_en',
                                   'project_name_en',
        
]]

# %%
# Try to split by year. Each year is a fold for cross validation
# Fit model on n folds and test on n+1 fold

# %%
# tmp = df_['actual_worth'].values
# tmp_norm = df_['actual_worth'].values / df_['actual_worth'].values.max()
# tmp_std = ((tmp - tmp.mean())/tmp.std())

# %%
OH_encoder = OneHotEncoder(handle_unknown='ignore', sparse_output=False)
OH_cols_train = pd.DataFrame(OH_encoder.fit_transform(df_sell_clean_ohe))

# One-hot encoding removed index; put it back
OH_cols_train.index = df_sell_clean.index
#OH_cols_valid.index = X_valid.index

# Remove categorical columns (will replace with one-hot encoding)
numeric_X_train = df_sell_clean.drop(df_sell_clean_ohe, axis=1)

# Add one-hot encoded columns to numerical features
new_X_train = pd.concat([numeric_X_train, OH_cols_train], axis=1)
#new_X_valid = pd.concat([numeric_X_valid, OH_cols_valid], axis=1)

#print(new_X_train)

# %%
Y_train = new_X_train[new_X_train['year'].isin([
                                            '2022',
                                          '2021',
                                         '2020',
                                         '2019',
                                         '2018',
                                         '2017',
                                         '2016'                                      
                                       ]
                                      )]['actual_worth']


X_train = new_X_train[new_X_train['year'].isin([
                                            '2022',
                                          '2021',
                                         '2020',
                                         '2019',
                                         '2018',
                                         '2017',
                                         '2016'
                                               ]
                                              )]
                                              
# X_test = new_X_train[new_X_train['year'] == '2023']
Y_test = new_X_train[new_X_train['year'] == '2023']['actual_worth']
X_test = new_X_train[new_X_train['year'] == '2023']


#X_train = new_X_train

X_train.drop(columns = ['year','actual_worth'], inplace = True)
X_test.drop(columns = ['year','actual_worth'], inplace = True)

# X_train.drop(columns = 'year', inplace = True)
# X_test.drop(columns = 'year', inplace = True)
# Out:
# /var/folders/_g/j20bjn4s0h39l0xcv3ph8w280000gq/T/ipykernel_27036/2786279964.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.drop(columns = ['year','actual_worth'], inplace = True)
# /var/folders/_g/j20bjn4s0h39l0xcv3ph8w280000gq/T/ipykernel_27036/2786279964.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.drop(columns = ['year','actual_worth'], inplace = True)

# %%
# df_tmp = df_[(df_['year'] == '2018') & \
#     (df_['procedure_name_en'] == 'Sell') & \
#    (df_['property_type_en'] == 'Unit')]

# %%
#df_tmp.groupby('procedure_area').count().head(50)

# %%
X_train = np.array(X_train)
Y_train = np.array(Y_train)

X_test = np.array(X_test)
Y_test = np.array(Y_test)

# %%
# X_train_max = np.max(X_train[:,0])
# X_test_max = np.max(X_test[:,0])

# X_train[:,0] = X_train[:,0] / X_train_max
# X_test[:,0] = X_test[:,0] / X_test_max


# Y_train_max = np.max(Y_train)
# Y_test_max = np.max(Y_test)

# Y_train = Y_train / Y_train_max
# Y_test = Y_test / Y_test_max

# %%
lr = LinearRegression()

regressor = DecisionTreeRegressor(max_depth=50)

xgb = xgboost.XGBRegressor(n_estimators=100, max_depth=20, eta=0.1, subsample=0.7, colsample_bytree=0.8)

rf = RandomForestRegressor(n_estimators=100, max_depth=100, random_state=47)

# %%
X_train
# Out:
# array([[190.17,   1.  ,   0.  , ...,   0.  ,   0.  ,   0.  ],
#        [116.07,   1.  ,   0.  , ...,   0.  ,   0.  ,   0.  ],
#        [ 67.46,   1.  ,   0.  , ...,   0.  ,   0.  ,   0.  ],
#        ...,
#        [175.53,   1.  ,   0.  , ...,   0.  ,   0.  ,   0.  ],
#        [187.64,   0.  ,   1.  , ...,   0.  ,   0.  ,   0.  ],
#        [ 43.59,   1.  ,   0.  , ...,   0.  ,   0.  ,   0.  ]])

# %%
lr.fit(X_train, Y_train)
Y_pred = lr.predict(X_test)
mean_absolute_error(Y_pred, Y_test)
print('LR_MAE: ',  mean_absolute_error(Y_pred, Y_test))

regressor.fit(X_train, Y_train)
Y_pred = regressor.predict(X_test)
mean_absolute_error(Y_pred, Y_test)
print('DecisionTree_MAE: ',  mean_absolute_error(Y_pred, Y_test))

xgb.fit(X_train, Y_train)
Y_pred = xgb.predict(X_test)
mean_absolute_error(Y_pred, Y_test)
print('XGB_MAE: ',  mean_absolute_error(Y_pred, Y_test))

rf.fit(X_train, Y_train)
Y_pred = rf.predict(X_test)
mean_absolute_error(Y_pred, Y_test)
print('RF_MAE: ',  mean_absolute_error(Y_pred, Y_test))
# Out:
# LR_MAE:  14106798413204.416
# DecisionTree_MAE:  471867.78580003104
# XGB_MAE:  442947.41607495485
# RF_MAE:  457935.42476467125

# %%
df_.groupby('property_sub_type_en').count()
# Out:
#                       instance_date  procedure_name_en  property_type_en
# property_sub_type_en
# Flat                         343632             343632            343632  \
# Gymnasium                        11                 11                11
# Hotel Apartment               18201              18201             18201
# Hotel Rooms                    8168               8168              8168
# Office                        42473              42473             42473
# Shop                           3722               3722              3722
# Show Rooms                        7                  7                 7
# Store                            39                 39                39
#
#                       property_usage_en  reg_type_en  area_name_en
# property_sub_type_en
# Flat                             343632       343632        343632  \
# Gymnasium                            11           11            11
# Hotel Apartment                   18201        18201         18201
# Hotel Rooms                        8168         8168          8168
# Office                            42473        42473         42473
# Shop                               3722         3722          3722
# Show Rooms                            7            7             7
# Store                                39           39            39
#
#                       building_name_en  project_name_en  master_project_en
# property_sub_type_en
# Flat                            343632           343632             343632  \
# Gymnasium                           11               11                 11
# Hotel Apartment                  18201            18201              18201
# Hotel Rooms                       8168             8168               8168
# Office                           42473            42473              42473
# Shop                              3722             3722               3722
# Show Rooms                           7                7                  7
# Store                               39               39                 39
#
#                       nearest_landmark_en  nearest_metro_en  nearest_mall_en
# property_sub_type_en
# Flat                               343632            343632           343632  \
# Gymnasium                              11                11               11
# Hotel Apartment                     18201             18201            18201
# Hotel Rooms                          8168              8168             8168
# Office                              42473             42473            42473
# Shop                                 3722              3722             3722
# Show Rooms                              7                 7                7
# Store                                  39                39               39
#
#                       rooms_en  has_parking  procedure_area  actual_worth
# property_sub_type_en
# Flat                    343632       343632          343632        343632  \
# Gymnasium                   11           11              11            11
# Hotel Apartment          18201        18201           18201         18201
# Hotel Rooms               8168         8168            8168          8168
# Office                   42473        42473           42473         42473
# Shop                      3722         3722            3722          3722
# Show Rooms                   7            7               7             7
# Store                       39           39              39            39
#
#                       meter_sale_price    year
# property_sub_type_en
# Flat                            343632  343632
# Gymnasium                           11      11
# Hotel Apartment                  18201   18201
# Hotel Rooms                       8168    8168
# Office                           42473   42473
# Shop                              3722    3722
# Show Rooms                           7       7
# Store                               39      39

# %%
#plt.hist(Y_test, bins=100)

# %%
# Try to separate dataset

# %%
df_sell['property_sub_type_en'].unique()
# Out:
# array(['Flat', 'Office', 'Shop', 'Hotel Apartment', 'Hotel Rooms',
#        'Store', 'Show Rooms'], dtype=object)

# %%
df_sell_office = df_sell[df_sell['property_sub_type_en'] == 'Flat']

# %%
# Percentile cut

# %%
df_sell_office = df_sell_office[(df_sell_office.actual_worth < df_sell_office.actual_worth.quantile(.80)) \
                                & (df_sell_office.actual_worth > df_sell_office.actual_worth.quantile(.10))]

# %%
# Trying to work only with OFFICE type

# %%
df_sell_office_clean = df_sell_office[
    [
#        'property_sub_type_en',
         'property_usage_en', 
         'nearest_landmark_en',
        'nearest_metro_en',
        'nearest_mall_en',
        'rooms_en',
        'has_parking',
        'procedure_area',
        'year',
        'actual_worth',
       'area_name_en',
       'building_name_en',
       'project_name_en',
        
]]

OH_encoder = OneHotEncoder(handle_unknown='ignore',
                           sparse_output = False,
                          dtype = int)

df_sell_office_clean_ohe = df_sell_office_clean[
    [
#                                 'property_sub_type_en',
                                  'property_usage_en',
                                  'nearest_landmark_en',
                                  'nearest_metro_en',
                                  'nearest_mall_en',
                                  'rooms_en',
                                  'has_parking',
                                  'area_name_en',
                                   'building_name_en',
                                   'project_name_en',
        
]]

# %%
df_sell_office_clean_ohe
# Out:
#         property_usage_en           nearest_landmark_en
# 521760        Residential  Sports City Swimming Academy  \
# 193605        Residential  Sports City Swimming Academy
# 1016984       Residential  Sports City Swimming Academy
# 1064465       Residential  Sports City Swimming Academy
# 15662         Residential  Sports City Swimming Academy
# ...                   ...                           ...
# 188995        Residential                    Motor City
# 499631        Residential                    Motor City
# 380930        Residential                    Motor City
# 360912        Residential                    Motor City
# 313875        Residential                    Motor City
#
#                 nearest_metro_en       nearest_mall_en rooms_en  has_parking
# 521760     Jumeirah Lakes Towers           Marina Mall    2 B/R            1  \
# 193605     Jumeirah Lakes Towers           Marina Mall    2 B/R            1
# 1016984    Jumeirah Lakes Towers           Marina Mall    2 B/R            1
# 1064465    Jumeirah Lakes Towers           Marina Mall    2 B/R            1
# 15662      Jumeirah Lakes Towers           Marina Mall    1 B/R            1
# ...                          ...                   ...      ...          ...
# 188995   Sharaf Dg Metro Station  Mall of the Emirates    1 B/R            1
# 499631   Sharaf Dg Metro Station  Mall of the Emirates    2 B/R            1
# 380930   Sharaf Dg Metro Station  Mall of the Emirates    2 B/R            1
# 360912   Sharaf Dg Metro Station  Mall of the Emirates    1 B/R            1
# 313875   Sharaf Dg Metro Station  Mall of the Emirates    2 B/R            1
#
#                    area_name_en building_name_en
# 521760         Al Thanyah Fifth       Bonnington  \
# 193605         Al Thanyah Fifth       Bonnington
# 1016984        Al Thanyah Fifth         AL SHERA
# 1064465        Al Thanyah Fifth         AL SHERA
# 15662          Al Thanyah Fifth       Bonnington
# ...                         ...              ...
# 188995   Al Barshaa South Third    The Wings - B
# 499631   Al Barshaa South Third    The Wings - B
# 380930   Al Barshaa South Third    The Wings - B
# 360912   Al Barshaa South Third    The Wings - B
# 313875   Al Barshaa South Third    The Wings - B
#
#                                   project_name_en
# 521760   BONNINGTON TOWER HOTEL & RESIDENCE DUBAI
# 193605   BONNINGTON TOWER HOTEL & RESIDENCE DUBAI
# 1016984                             ALSHERA TOWER
# 1064465                             ALSHERA TOWER
# 15662    BONNINGTON TOWER HOTEL & RESIDENCE DUBAI
# ...                                           ...
# 188995                                  THE WINGS
# 499631                                  THE WINGS
# 380930                                  THE WINGS
# 360912                                  THE WINGS
# 313875                                  THE WINGS
#
# [56600 rows x 9 columns]

# %%
OH_encoder = OneHotEncoder(handle_unknown='infrequent_if_exist',
                           sparse_output=False,
                          drop='first')

OH_cols_train = pd.DataFrame(OH_encoder.fit_transform(df_sell_office_clean_ohe))

# One-hot encoding removed index; put it back
OH_cols_train.index = df_sell_office_clean_ohe.index
#OH_cols_valid.index = X_valid.index

# Remove categorical columns (will replace with one-hot encoding)
numeric_X_train = df_sell_office_clean.drop(df_sell_office_clean_ohe, axis=1)

# Add one-hot encoded columns to numerical features
new_X_train = pd.concat([numeric_X_train, OH_cols_train], axis=1)
#new_X_valid = pd.concat([numeric_X_valid, OH_cols_valid], axis=1)

#print(new_X_train)

# %%
Y_train = new_X_train[new_X_train['year'].isin([
                                            '2022',
                                          '2021',
                                         '2020',
                                         '2019',
                                         '2018',
                       aa                  '2017',
                                         '2016',
                                            '2015','2014','2013','2012','2011','2010'
                                       ]
                                      )]['actual_worth']


X_train = new_X_train[new_X_train['year'].isin([
                                            '2022',
                                          '2021',
                                         '2020',
                                         '2019',
                                         '2018',
                                         '2017',
                                         '2016',
                                            '2015','2014','2013','2012','2011','2010'
                                               ]
                                              )]
                                              
# X_test = new_X_train[new_X_train['year'] == '2023']
Y_test = new_X_train[new_X_train['year'] == '2023']['actual_worth']
X_test = new_X_train[new_X_train['year'] == '2023']


#X_train = new_X_train

X_train.drop(columns = ['year','actual_worth'], inplace = True)
X_test.drop(columns = ['year','actual_worth'], inplace = True)

# X_train.drop(columns = 'year', inplace = True)
# X_test.drop(columns = 'year', inplace = True)
# Out:
# /var/folders/_g/j20bjn4s0h39l0xcv3ph8w280000gq/T/ipykernel_40756/1821612459.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.drop(columns = ['year','actual_worth'], inplace = True)
# /var/folders/_g/j20bjn4s0h39l0xcv3ph8w280000gq/T/ipykernel_40756/1821612459.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.drop(columns = ['year','actual_worth'], inplace = True)

# %%
X_train = np.array(X_train)
Y_train = np.array(Y_train)

X_test = np.array(X_test)
Y_test = np.array(Y_test)

# %%
lr = LinearRegression()

regressor = DecisionTreeRegressor(max_depth=50)

xgb = xgboost.XGBRegressor(n_estimators=1000, max_depth=10, eta=0.1, subsample=0.7, colsample_bytree=0.8)

rf = RandomForestRegressor(n_estimators=500, max_depth=200, random_state=47)

# %%
# lr.fit(X_train, Y_train)
# Y_pred = lr.predict(X_test)
# mean_absolute_error(Y_pred, Y_test)
# print('LR_MAE: ',  mean_absolute_error(Y_pred, Y_test))

# regressor.fit(X_train, Y_train)
# Y_pred = regressor.predict(X_test)
# mean_absolute_error(Y_pred, Y_test)
# print('DecisionTree_MAE: ',  mean_absolute_error(Y_pred, Y_test))

xgb.fit(X_train, Y_train)
Y_pred = xgb.predict(X_test)
mean_absolute_error(Y_pred, Y_test)
print('XGB_MAE: ',  mean_absolute_error(Y_pred, Y_test))

# rf.fit(X_train, Y_train)
# Y_pred = rf.predict(X_test)
# mean_absolute_error(Y_pred, Y_test)
# print('RF_MAE: ',  mean_absolute_error(Y_pred, Y_test))
# Out:
# XGB_MAE:  161694.2776796789

# %%
new_X_train['actual_worth'].mean()
# Out:
# 1124620.2049098506

# %%
df_sell_office_clean['actual_worth'].mean()
# Out:
# 1124620.2049098506

# %%
df_sell_office_clean['actual_worth'].min()
# Out:
# 400026.0

# %%
262837.22642949666/ 1124620.2049098506
# Out:
# 0.23371199030748843

# %%
##################################################################################################################################
######################################## PLAYING WITH TARGET ENCODING ############################################################
######################################### Frequency count ###############################################################

# %%
import numpy as np
import pandas as pd

from sklearn.base import BaseEstimator, TransformerMixin

class TargetEncode(BaseEstimator, TransformerMixin):
    
    def __init__(self, categories='auto', k=1, f=1, 
                 noise_level=0, random_state=None):
        if type(categories)==str and categories!='auto':
            self.categories = [categories]
        else:
            self.categories = categories
        self.k = k
        self.f = f
        self.noise_level = noise_level
        self.encodings = dict()
        self.prior = None
        self.random_state = random_state
        
    def add_noise(self, series, noise_level):
        return series * (1 + noise_level *   
                         np.random.randn(len(series)))
        
    def fit(self, X, y=None):
        if type(self.categories)=='auto':
            self.categories = np.where(X.dtypes == type(object()))[0]
        
        temp = X.loc[:, self.categories].copy()
        temp['target'] = y
        self.prior = np.mean(y)
        for variable in self.categories:
            avg = (temp.groupby(by=variable)['target']
                       .agg(['mean', 'count']))
            # Compute smoothing 
            smoothing = (1 / (1 + np.exp(-(avg['count'] - self.k) /                 
                         self.f)))
            # The bigger the count the less full_avg is accounted
            self.encodings[variable] = dict(self.prior * (1 -  
                             smoothing) + avg['mean'] * smoothing)
            
        return self
    
    def transform(self, X):
        Xt = X.copy()
        for variable in self.categories:
            Xt[variable].replace(self.encodings[variable], 
                                 inplace=True)
            unknown_value = {value:self.prior for value in 
                             X[variable].unique() 
                             if value not in 
                             self.encodings[variable].keys()}
            if len(unknown_value) > 0:
                Xt[variable].replace(unknown_value, inplace=True)
            Xt[variable] = Xt[variable].astype(float)
            if self.noise_level > 0:
                if self.random_state is not None:
                    np.random.seed(self.random_state)
                Xt[variable] = self.add_noise(Xt[variable], 
                                              self.noise_level)
        return Xt
    
    def fit_transform(self, X, y=None):
        self.fit(X, y)
        return self.transform(X)

# %%
df = pd.read_csv('/Users/a.evdakimov/Transactions.csv')


#df = df[df['actual_worth'] <= 1000000]


df_ = df[
    ['instance_date',
    'procedure_name_en',
   'property_type_en',
   'property_sub_type_en',
   'property_usage_en',
   'reg_type_en',
   'area_name_en',
   'building_name_en',
   'project_name_en',
   'master_project_en',
   'nearest_landmark_en',
   'nearest_metro_en',
   'nearest_mall_en',
   'rooms_en',
   'has_parking',
   'procedure_area',
    'actual_worth',
    'meter_sale_price']
  ]

df_ = df_.dropna()

df_['date'] = df_['instance_date'].apply(lambda x: x[-4:]) + '-' + df_['instance_date'].apply(lambda x: x[3:5]) + df_['instance_date'].apply(lambda x: x[5:7])
df_['year'] = df_['date'].apply(lambda x: x[:-5])

df_['date'] = pd.to_datetime(df_['date'])
df_ = df_.sort_values(by='date')



df_sell = df_[df_['procedure_name_en'] == 'Sell']

df_flat = df_sell[df_sell['property_sub_type_en'] == 'Flat']



df_flat.drop(columns = [
                    #'procedure_name_en',
#                        'property_sub_type_en',
#                        'property_type_en',
                       'instance_date',
#                       'property_usage_en',
#                       'reg_type_en',
#                       'meter_sale_price'
                    ], inplace = True)
# Out:
# /var/folders/_g/j20bjn4s0h39l0xcv3ph8w280000gq/T/ipykernel_27036/3441694893.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_flat.drop(columns = [

# %%
df_flat = df_flat[(df_flat.actual_worth < df_flat.actual_worth.quantile(.80)) \
                                & (df_flat.actual_worth > df_flat.actual_worth.quantile(.10))]

# %%
#### Making frequency feature


def freq_counter(df, ids):
    
    ids = df['id'].unique()
    
    d = {k:0 for k in ids}

    for row in df_flat.iterrows():
    
        if int(row[1]['id']) in ids:
            
            d[row[1]['id']] += 1
        
            df.loc[row[0],'freq'] = d[row[1]['id']]
    
    return df


def add_stringify(row):
    cols = ['procedure_name_en', 'property_type_en',
       'property_sub_type_en', 'property_usage_en', 'reg_type_en',
       'area_name_en', 'building_name_en', 'project_name_en',
       'master_project_en', 'nearest_landmark_en', 'nearest_metro_en',
       'nearest_mall_en', 'rooms_en', 'has_parking', 'procedure_area']
    
    tmp = [str(row[i]) for i in cols]
    tmp1 = str()
    
    for i in tmp:
        tmp1+=i
        
    return abs(hash(str(tmp1)))


df_flat['id'] = df_flat.apply(add_stringify, axis=1)
df_flat['freq'] = 0


ids = df_flat['id'].unique()
d = {k:0 for k in ids}

for row in df_flat.iterrows():
#    print(row[1]['id'])
    
    if int(row[1]['id']) in ids:
        
        d[row[1]['id']] += 1
        
        df_flat.loc[row[0],'freq'] = d[row[1]['id']]

# %%
df_flat.drop(columns = [
                    'procedure_name_en',
                        'property_sub_type_en',
                        'property_type_en',
                       'property_usage_en',
                       'reg_type_en',
                       'meter_sale_price',
    
                        'date',
                            'id'
                    ], inplace = True)

# %%
df_flat_train = df_flat[df_flat['year'].isin(['2016',
                                             '2017',
                                             '2018',
                                            '2019',
                                            '2020',
                                            '2021',
                                            '2022'])]

df_flat_test = df_flat[df_flat['year'].isin(['2023'])]

# %%
ohe = ['area_name_en',
       'building_name_en',
       'project_name_en',
       'master_project_en',
       'nearest_landmark_en',
      'nearest_metro_en',
      'nearest_mall_en',
      'rooms_en',
      'has_parking']

# %%
#Instantiate TargetEncode class

te = TargetEncode(categories=ohe)
te.fit(df_flat, df_flat['actual_worth'])

df_flat_encoded = te.transform(df_flat)

# %%
Y_train = df_flat_encoded[df_flat_encoded['year'].isin([
                                            '2022',
                                          '2021',
                                         '2020',
                                         '2019',
                                         '2018',
                                         '2017',
                                         '2016',
                                            '2015','2014','2013','2012','2011','2010'
                                       ]
                                      )]['actual_worth']


X_train = df_flat_encoded[df_flat_encoded['year'].isin([
                                            '2022',
                                          '2021',
                                         '2020',
                                         '2019',
                                         '2018',
                                         '2017',
                                         '2016',
                                            '2015','2014','2013','2012','2011','2010'
                                               ]
                                              )]
                                              
# X_test = new_X_train[new_X_train['year'] == '2023']
Y_test = df_flat_encoded[df_flat_encoded['year'] == '2023']['actual_worth']
X_test = df_flat_encoded[df_flat_encoded['year'] == '2023']


#X_train = new_X_train

X_train.drop(columns = ['year','actual_worth'], inplace = True)
X_test.drop(columns = ['year','actual_worth'], inplace = True)

# X_train.drop(columns = 'year', inplace = True)
# X_test.drop(columns = 'year', inplace = True)

X_train = normalize(np.array(X_train))
Y_train = np.array(Y_train)

X_test = normalize(np.array(X_test))
Y_test = np.array(Y_test)



# X_train = normalize(X_train)
# Y_train = normalize(Y_train)

# X_test = normalize(X_test)
# Y_test = normalize(Y_test)
# Out:
# /var/folders/_g/j20bjn4s0h39l0xcv3ph8w280000gq/T/ipykernel_27036/1820002149.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.drop(columns = ['year','actual_worth'], inplace = True)
# /var/folders/_g/j20bjn4s0h39l0xcv3ph8w280000gq/T/ipykernel_27036/1820002149.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.drop(columns = ['year','actual_worth'], inplace = True)

# %%
lr = LinearRegression()

regressor = DecisionTreeRegressor(max_depth=50)

xgb = xgboost.XGBRegressor(n_estimators=100, max_depth=10, eta=0.1, subsample=0.7, colsample_bytree=0.8)

rf = RandomForestRegressor(n_estimators=300, max_depth=100, random_state=47)

# %%
# lr.fit(X_train, Y_train)
# Y_pred = lr.predict(X_test)
# mean_absolute_error(Y_pred, Y_test)
# print('LR_MAE: ',  mean_absolute_error(Y_pred, Y_test))

regressor.fit(X_train, Y_train)
Y_pred = regressor.predict(X_test)
mean_absolute_error(Y_pred, Y_test)
print('DecisionTree_MAE: ',  mean_absolute_error(Y_pred, Y_test),
          'DecisionTree_RMSE: ', root_mean_squared_error(Y_pred, Y_test))

xgb.fit(X_train, Y_train)
Y_pred = xgb.predict(X_test)
mean_absolute_error(Y_pred, Y_test)
print('XGB_MAE: ',  mean_absolute_error(Y_pred, Y_test),
     'XGB_RMSE: ', root_mean_squared_error(Y_pred, Y_test))

# rf.fit(X_train, Y_train)
# Y_pred = rf.predict(X_test)
# mean_absolute_error(Y_pred, Y_test)
# print('RF_MAE: ',  mean_absolute_error(Y_pred, Y_test),
#      'XGB_RMSE: ', root_mean_squared_error(Y_pred, Y_test))
# Out:
# DecisionTree_MAE:  191174.87372010344 DecisionTree_RMSE:  260706.2148941464
# XGB_MAE:  158695.27335153936 XGB_RMSE:  209231.12493507785

# %%
158695.27335153936/ df_flat_encoded['actual_worth'].mean()
# Out:
# 0.16367237343301447

# %%
158695.27335153936/ df_flat_encoded['actual_worth'].max()
# Out:
# 0.08465481642722529

# %%
X_test[0]
# Out:
# array([3.51527081e-01, 3.09878142e-01, 3.09878142e-01, 2.84877218e-01,
#        3.77447451e-01, 2.96438531e-01, 3.90812525e-01, 3.26004987e-01,
#        3.37444358e-01, 2.27425063e-05, 4.50758625e-06])

# %%
df_flat_encoded['actual_worth'].mean()
# Out:
# 969591.0801738813

# %%
# Additional features:
# selling frequency
# number of transactions passed in area

# %%
pre_years = ['2007', '2008', '2009', '2010',
            '2011', '2012', '2013', '2014', '2015']

# %%
# Get areas and counters

# %%
############################## Get areas and counters ##########################################################################################
############################## 2007 - 2014 for pre counting ############################################################
########################################################################################################################

# %%
df = pd.read_csv('/Users/a.evdakimov/Transactions.csv')


#df = df[df['actual_worth'] <= 1000000]


df_ = df[
    ['instance_date',
    'procedure_name_en',
   'property_type_en',
   'property_sub_type_en',
   'property_usage_en',
   'reg_type_en',
   'area_name_en',
   'building_name_en',
   'project_name_en',
   'master_project_en',
   'nearest_landmark_en',
   'nearest_metro_en',
   'nearest_mall_en',
   'rooms_en',
   'has_parking',
   'procedure_area',
    'actual_worth',
    'meter_sale_price']
  ]

df_ = df_.dropna()

df_['date'] = df_['instance_date'].apply(lambda x: x[-4:]) + '-' + df_['instance_date'].apply(lambda x: x[3:5]) + df_['instance_date'].apply(lambda x: x[5:7])
df_['year'] = df_['date'].apply(lambda x: x[:-5])

df_['date'] = pd.to_datetime(df_['date'])
df_ = df_.sort_values(by='date')



df_sell = df_[df_['procedure_name_en'] == 'Sell']

df_flat = df_sell[df_sell['property_sub_type_en'] == 'Flat']



df_flat.drop(columns = [
                    #'procedure_name_en',
#                        'property_sub_type_en',
#                        'property_type_en',
                       'instance_date',
#                       'property_usage_en',
#                       'reg_type_en',
#                       'meter_sale_price'
                    ], inplace = True)


df_flat = df_flat[(df_flat.actual_worth < df_flat.actual_worth.quantile(.80)) \
                                & (df_flat.actual_worth > df_flat.actual_worth.quantile(.10))]


############################# Adding Unique ID for estate obj ########################################################
df_flat['id'] = df_flat.apply(add_stringify, axis=1)
df_flat['freq'] = 0



ids = df_flat['id'].unique()
d = {k:0 for k in ids}

for row in df_flat.iterrows():
    
    if int(row[1]['id']) in ids:        
        d[row[1]['id']] += 1
        df_flat.loc[row[0],'freq'] = d[row[1]['id']]

        
        
############################## Adding number of unique id's in given building and area ############################
df_flat['area_name_freq'] = 1
df_flat['building_name_freq'] = 1

ids_set = set(df_flat['id'].unique())

areas_dict_counter = {k:0 for k in df_flat.area_name_en.unique()}
building_dict_counter = {k:0 for k in df_flat.building_name_en.unique()}


for row in df_flat.iterrows():
    
        
    idd = row[1]['id']
        
    if row[1]['id'] in ids_set:
        areas_dict_counter[row[1]['area_name_en']] += 1
    
        df_flat.loc[row[0],'area_name_freq'] = areas_dict_counter[row[1]['area_name_en']]
        ids_set.remove(idd)
    else:
        df_flat.loc[row[0],'area_name_freq'] = areas_dict_counter[row[1]['area_name_en']]
        
        
ids_set = set(df_flat['id'].unique())
for row in df_flat.iterrows():
    
        
    idd = row[1]['id']
        
    if row[1]['id'] in ids_set:
        building_dict_counter[row[1]['building_name_en']] += 1
    
        df_flat.loc[row[0],'building_name_freq'] = building_dict_counter[row[1]['building_name_en']]
        ids_set.remove(idd)
    else:
        df_flat.loc[row[0],'building_name_freq'] = building_dict_counter[row[1]['building_name_en']]
        

############################ Unique ids in given project and master project ##########################################

ids_set = set(df_flat['id'].unique())

df_flat['proj_freq'] = 1
df_flat['master_proj_freq'] = 1

project_dict_counter = {k:0 for k in df_flat.project_name_en.unique()}
master_project_dict_counter = {k:0 for k in df_flat.master_project_en.unique()}



for row in df_flat.iterrows():
    
        
    idd = row[1]['id']
        
    if row[1]['id'] in ids_set:
        project_dict_counter[row[1]['project_name_en']] += 1
    
        df_flat.loc[row[0],'proj_freq'] = project_dict_counter[row[1]['project_name_en']]
        ids_set.remove(idd)
    else:
        df_flat.loc[row[0],'proj_freq'] = project_dict_counter[row[1]['project_name_en']]

        
ids_set = set(df_flat['id'].unique())        
for row in df_flat.iterrows():
    
        
    idd = row[1]['id']
        
    if row[1]['id'] in ids_set:
        master_project_dict_counter[row[1]['master_project_en']] += 1
    
        df_flat.loc[row[0],'master_proj_freq'] = master_project_dict_counter[row[1]['master_project_en']]
        ids_set.remove(idd)
    else:
        df_flat.loc[row[0],'master_proj_freq'] = master_project_dict_counter[row[1]['master_project_en']]
        
        
########################### Total procedure area in given ###########################
########################### building_name/area_name/project/master_project ###########################

df_flat['total_building_area'] = 0
df_flat['total_areaname_area'] = 0
df_flat['total_project_area'] = 0
df_flat['total_master_project_area'] = 0


areas_dict_counter = {k:0 for k in df_flat.area_name_en.unique()}
building_dict_counter = {k:0 for k in df_flat.building_name_en.unique()}
project_dict_counter = {k:0 for k in df_flat.project_name_en.unique()}
master_project_dict_counter = {k:0 for k in df_flat.master_project_en.unique()}



ids_set = set(df_flat['id'].unique())        
for row in df_flat.iterrows():
    
        
    idd = row[1]['id']
        
    if row[1]['id'] in ids_set:
        areas_dict_counter[row[1]['area_name_en']] += row[1]['procedure_area']
    
        df_flat.loc[row[0],'total_areaname_area'] = areas_dict_counter[row[1]['area_name_en']]
        ids_set.remove(idd)
    else:
        df_flat.loc[row[0],'total_areaname_area'] = areas_dict_counter[row[1]['area_name_en']]

        
        

ids_set = set(df_flat['id'].unique())        
for row in df_flat.iterrows():
    
        
    idd = row[1]['id']
        
    if row[1]['id'] in ids_set:
        building_dict_counter[row[1]['building_name_en']] += row[1]['procedure_area']
    
        df_flat.loc[row[0],'total_building_area'] = building_dict_counter[row[1]['building_name_en']]
        ids_set.remove(idd)
    else:
        df_flat.loc[row[0],'total_building_area'] = building_dict_counter[row[1]['building_name_en']]
        

        
ids_set = set(df_flat['id'].unique())        
for row in df_flat.iterrows():
    
        
    idd = row[1]['id']
        
    if row[1]['id'] in ids_set:
        project_dict_counter[row[1]['project_name_en']] += row[1]['procedure_area']
    
        df_flat.loc[row[0],'total_project_area'] = project_dict_counter[row[1]['project_name_en']]
        ids_set.remove(idd)
    else:
        df_flat.loc[row[0],'total_project_area'] = project_dict_counter[row[1]['project_name_en']]



ids_set = set(df_flat['id'].unique())        
for row in df_flat.iterrows():
    
        
    idd = row[1]['id']
        
    if row[1]['id'] in ids_set:
        master_project_dict_counter[row[1]['master_project_en']] += row[1]['procedure_area']
    
        df_flat.loc[row[0],'total_master_project_area'] = master_project_dict_counter[row[1]['master_project_en']]
        ids_set.remove(idd)
    else:
        df_flat.loc[row[0],'total_master_project_area'] = master_project_dict_counter[row[1]['master_project_en']]


        
########################### Frequencies of nearest_metro/landmark/mall ######################################################
##################################################################################################################################################################
        
metro_dict_counter = {k:0 for k in df_flat.nearest_metro_en.unique()}
landmark_dict_counter = {k:0 for k in df_flat.nearest_landmark_en.unique()}
mall_dict_counter = {k:0 for k in df_flat.nearest_mall_en.unique()}
    
    
df_flat['nearest_metro_en_freq'] = 0
df_flat['nearest_landmark_en_freq'] = 0
df_flat['nearest_mall_en_freq'] = 0


ids_set = set(df_flat['id'].unique())        
for row in df_flat.iterrows():
    
        
    idd = row[1]['id']
        
    if row[1]['id'] in ids_set:
        metro_dict_counter[row[1]['nearest_metro_en']] += 1
    
        df_flat.loc[row[0],'nearest_metro_en_freq'] = metro_dict_counter[row[1]['nearest_metro_en']]
        ids_set.remove(idd)
    else:
        df_flat.loc[row[0],'nearest_metro_en_freq'] = metro_dict_counter[row[1]['nearest_metro_en']]

      
    
ids_set = set(df_flat['id'].unique())        
for row in df_flat.iterrows():
    
        
    idd = row[1]['id']
        
    if row[1]['id'] in ids_set:
        landmark_dict_counter[row[1]['nearest_landmark_en']] += 1
    
        df_flat.loc[row[0],'nearest_landmark_en_freq'] = landmark_dict_counter[row[1]['nearest_landmark_en']]
        ids_set.remove(idd)
    else:
        df_flat.loc[row[0],'nearest_landmark_en_freq'] = landmark_dict_counter[row[1]['nearest_landmark_en']]

        
        
ids_set = set(df_flat['id'].unique())        
for row in df_flat.iterrows():
    
        
    idd = row[1]['id']
        
    if row[1]['id'] in ids_set:
        mall_dict_counter[row[1]['nearest_mall_en']] += 1
    
        df_flat.loc[row[0],'nearest_mall_en_freq'] = mall_dict_counter[row[1]['nearest_mall_en']]
        ids_set.remove(idd)
    else:
        df_flat.loc[row[0],'nearest_mall_en_freq'] = mall_dict_counter[row[1]['nearest_mall_en']]



########################### Frequencies of nearest_metro/landmark/mall #####################################################
########################################### Including resellings#################################################################################
##################################################################################################################################################################
    
        
        
########################### Total ACTUAL_WORTH in given ######################################################
########################### building_name/area_name/project/master_project ######################################################

areas_dict_counter = {k:0 for k in df_flat.area_name_en.unique()}
building_dict_counter = {k:0 for k in df_flat.building_name_en.unique()}
project_dict_counter = {k:0 for k in df_flat.project_name_en.unique()}
master_project_dict_counter = {k:0 for k in df_flat.master_project_en.unique()}



        
df_flat.drop(columns = [
                    'procedure_name_en',
                        'property_sub_type_en',
                        'property_type_en',
                       'property_usage_en',
                       'reg_type_en',
                       'meter_sale_price',
    
                        'date',
#                            'id'
                    ], inplace = True)
# Out:
# /var/folders/_g/j20bjn4s0h39l0xcv3ph8w280000gq/T/ipykernel_49605/3715257643.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_flat.drop(columns = [

# %%
df_flat_ = df_flat.drop(columns = ['id'], inplace = False) 

df_flat_train_ = df_flat[df_flat['year'].isin([
                                            '2007', '2008','2009',
                                            '2010','2011','2012','2013','2014','2015','2016',
                                             '2017',
                                             '2018',
                                            '2019',
                                            '2020',
                                            '2021',
                                            '2022'])].drop(columns = ['id'], inplace = False)

df_flat_test_ = df_flat[df_flat['year'].isin(['2023'])]


df_flat_train = df_flat[df_flat['year'].isin([
                                            '2007', '2008','2009',
                                            '2010','2011','2012','2013','2014','2015','2016',
                                             '2017',
                                             '2018',
                                            '2019',
                                            '2020',
                                            '2021',
                                            '2022'])].drop(columns = ['id'], inplace = False)

df_flat_test = df_flat[df_flat['year'].isin(['2023'])]


ohe = ['area_name_en',
       'building_name_en',
       'project_name_en',
       'master_project_en',
       'nearest_landmark_en',
      'nearest_metro_en',
      'nearest_mall_en',
      'rooms_en',
      'has_parking']

# %%
#Instantiate TargetEncode class

te = TargetEncode(categories=ohe)
te.fit(df_flat_, df_flat_['actual_worth'])

df_flat_encoded = te.transform(df_flat_)

# %%
Y_train = df_flat_encoded[df_flat_encoded['year'].isin([
                                            '2022',
                                          '2021',
                                         '2020',
                                         '2019',
                                         '2018',
                                         '2017',
                                         '2016',
                                            '2015','2014','2013','2012','2011','2010',
                                            '2007', '2008','2009',

                                       ]
                                      )]['actual_worth']


X_train = df_flat_encoded[df_flat_encoded['year'].isin([
                                            '2022',
                                          '2021',
                                         '2020',
                                         '2019',
                                         '2018',
                                         '2017',
                                         '2016',
                                            '2015','2014','2013','2012','2011','2010',
                                            '2007', '2008','2009',

                                               ]
                                              )]
                                              
# X_test = new_X_train[new_X_train['year'] == '2023']
Y_test = df_flat_encoded[df_flat_encoded['year'] == '2023']['actual_worth']
X_test = df_flat_encoded[df_flat_encoded['year'] == '2023']


#X_train = new_X_train

X_train.drop(columns = ['year','actual_worth'], inplace = True)
X_test.drop(columns = ['year','actual_worth'], inplace = True)

# X_train.drop(columns = 'year', inplace = True)
# X_test.drop(columns = 'year', inplace = True)

X_train = normalize(np.array(X_train))
Y_train = np.array(Y_train)

X_test = normalize(np.array(X_test))
Y_test = np.array(Y_test)



# X_train = normalize(X_train)
# Y_train = normalize(Y_train)

# X_test = normalize(X_test)
# Y_test = normalize(Y_test)
# Out:
# /var/folders/_g/j20bjn4s0h39l0xcv3ph8w280000gq/T/ipykernel_49605/489515300.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.drop(columns = ['year','actual_worth'], inplace = True)
# /var/folders/_g/j20bjn4s0h39l0xcv3ph8w280000gq/T/ipykernel_49605/489515300.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.drop(columns = ['year','actual_worth'], inplace = True)

# %%
lr = LinearRegression()

regressor = DecisionTreeRegressor(max_depth=50)

xgb = xgboost.XGBRegressor(n_estimators=500, max_depth=10, eta=0.1, subsample=0.7, colsample_bytree=0.8)

rf = RandomForestRegressor(n_estimators=300, max_depth=100, random_state=47)

# %%
# lr.fit(X_train, Y_train)
# Y_pred = lr.predict(X_test)
# mean_absolute_error(Y_pred, Y_test)
# print('LR_MAE: ',  mean_absolute_error(Y_pred, Y_test))

regressor.fit(X_train, Y_train)
Y_pred = regressor.predict(X_test)
mean_absolute_error(Y_pred, Y_test)
print('DecisionTree_MAE: ',  mean_absolute_error(Y_pred, Y_test),
          'DecisionTree_RMSE: ', root_mean_squared_error(Y_pred, Y_test),
     'Decision_Tree_R2: ', r2_score(Y_pred, Y_test))

xgb.fit(X_train, Y_train)
Y_pred = xgb.predict(X_test)
mean_absolute_error(Y_pred, Y_test)
print('XGB_MAE: ',  mean_absolute_error(Y_pred, Y_test),
     'XGB_RMSE: ', root_mean_squared_error(Y_pred, Y_test),
          'XGB_R2: ', r2_score(Y_pred, Y_test))

# rf.fit(X_train, Y_train)
# Y_pred = rf.predict(X_test)
# mean_absolute_error(Y_pred, Y_test)
# print('RF_MAE: ',  mean_absolute_error(Y_pred, Y_test),
#      'XGB_RMSE: ', root_mean_squared_error(Y_pred, Y_test))
# Out:
# DecisionTree_MAE:  176075.8129496403 DecisionTree_RMSE:  243158.65905408052 Decision_Tree_R2:  0.568114182821968
# XGB_MAE:  129355.36953158061 XGB_RMSE:  178749.6593763993 XGB_R2:  0.7280936595722528

# %%
##############################################################################################################
##############################################################################################################
##############################################################################################################

# %%
df_flat.head(50)
# Out:
#              area_name_en building_name_en project_name_en
# 547865        Marsa Dubai        BELVEDERE   THE BELVEDERE  \
# 399216        Marsa Dubai        BELVEDERE   THE BELVEDERE
# 620008        Marsa Dubai        BELVEDERE   THE BELVEDERE
# 470785        Marsa Dubai        BELVEDERE   THE BELVEDERE
# 252430        Marsa Dubai        BELVEDERE   THE BELVEDERE
# 405017        Marsa Dubai        BELVEDERE   THE BELVEDERE
# 850020        Marsa Dubai        BELVEDERE   THE BELVEDERE
# 35347         Marsa Dubai        BELVEDERE   THE BELVEDERE
# 232381        Marsa Dubai        BELVEDERE   THE BELVEDERE
# 196285        Marsa Dubai        BELVEDERE   THE BELVEDERE
# 39744         Marsa Dubai        BELVEDERE   THE BELVEDERE
# 122903        Marsa Dubai        BELVEDERE   THE BELVEDERE
# 436568        Marsa Dubai        BELVEDERE   THE BELVEDERE
# 167616        Marsa Dubai        BELVEDERE   THE BELVEDERE
# 228538        Marsa Dubai        BELVEDERE   THE BELVEDERE
# 577284        Marsa Dubai        BELVEDERE   THE BELVEDERE
# 9742          Marsa Dubai        BELVEDERE   THE BELVEDERE
# 835637        Marsa Dubai        BELVEDERE   THE BELVEDERE
# 883995        Marsa Dubai        BELVEDERE   THE BELVEDERE
# 727712        Marsa Dubai        BELVEDERE   THE BELVEDERE
# 366846        Marsa Dubai        BELVEDERE   THE BELVEDERE
# 901960        Marsa Dubai        BELVEDERE   THE BELVEDERE
# 851118        Marsa Dubai        BELVEDERE   THE BELVEDERE
# 439815        Marsa Dubai        BELVEDERE   THE BELVEDERE
# 623378        Marsa Dubai        BELVEDERE   THE BELVEDERE
# 885535        Marsa Dubai        BELVEDERE   THE BELVEDERE
# 1119658       Marsa Dubai        BELVEDERE   THE BELVEDERE
# 749867        Marsa Dubai        BELVEDERE   THE BELVEDERE
# 920998        Marsa Dubai        BELVEDERE   THE BELVEDERE
# 192680        Marsa Dubai        BELVEDERE   THE BELVEDERE
# 501206        Marsa Dubai        BELVEDERE   THE BELVEDERE
# 498071        Marsa Dubai        BELVEDERE   THE BELVEDERE
# 1095134       Marsa Dubai        BELVEDERE   THE BELVEDERE
# 176960        Marsa Dubai        BELVEDERE   THE BELVEDERE
# 380696        Marsa Dubai        BELVEDERE   THE BELVEDERE
# 938960        Marsa Dubai        BELVEDERE   THE BELVEDERE
# 985876        Marsa Dubai        BELVEDERE   THE BELVEDERE
# 270332        Marsa Dubai        BELVEDERE   THE BELVEDERE
# 854383        Marsa Dubai        BELVEDERE   THE BELVEDERE
# 494749        Marsa Dubai        BELVEDERE   THE BELVEDERE
# 247422        Marsa Dubai        BELVEDERE   THE BELVEDERE
# 315149   Al Thanyah Fifth           SABA 2    SABA TOWER 2
# 349253   Al Thanyah Fifth           SABA 3    SABA TOWER 3
# 357613   Al Thanyah Fifth           SABA 2    SABA TOWER 2
# 781013   Al Thanyah Fifth           SABA 2    SABA TOWER 2
# 548005   Al Thanyah Fifth           SABA 3    SABA TOWER 3
# 386588   Al Thanyah Fifth           SABA 3    SABA TOWER 3
# 736520   Al Thanyah Fifth           SABA 2    SABA TOWER 2
# 201808   Al Thanyah Fifth           SABA 2    SABA TOWER 2
# 379564   Al Thanyah Fifth           SABA 3    SABA TOWER 3
#
#              master_project_en           nearest_landmark_en
# 547865            Dubai Marina  Sports City Swimming Academy  \
# 399216            Dubai Marina  Sports City Swimming Academy
# 620008            Dubai Marina  Sports City Swimming Academy
# 470785            Dubai Marina  Sports City Swimming Academy
# 252430            Dubai Marina  Sports City Swimming Academy
# 405017            Dubai Marina  Sports City Swimming Academy
# 850020            Dubai Marina  Sports City Swimming Academy
# 35347             Dubai Marina  Sports City Swimming Academy
# 232381            Dubai Marina  Sports City Swimming Academy
# 196285            Dubai Marina  Sports City Swimming Academy
# 39744             Dubai Marina  Sports City Swimming Academy
# 122903            Dubai Marina  Sports City Swimming Academy
# 436568            Dubai Marina  Sports City Swimming Academy
# 167616            Dubai Marina  Sports City Swimming Academy
# 228538            Dubai Marina  Sports City Swimming Academy
# 577284            Dubai Marina  Sports City Swimming Academy
# 9742              Dubai Marina  Sports City Swimming Academy
# 835637            Dubai Marina  Sports City Swimming Academy
# 883995            Dubai Marina  Sports City Swimming Academy
# 727712            Dubai Marina  Sports City Swimming Academy
# 366846            Dubai Marina  Sports City Swimming Academy
# 901960            Dubai Marina  Sports City Swimming Academy
# 851118            Dubai Marina  Sports City Swimming Academy
# 439815            Dubai Marina  Sports City Swimming Academy
# 623378            Dubai Marina  Sports City Swimming Academy
# 885535            Dubai Marina  Sports City Swimming Academy
# 1119658           Dubai Marina  Sports City Swimming Academy
# 749867            Dubai Marina  Sports City Swimming Academy
# 920998            Dubai Marina  Sports City Swimming Academy
# 192680            Dubai Marina  Sports City Swimming Academy
# 501206            Dubai Marina  Sports City Swimming Academy
# 498071            Dubai Marina  Sports City Swimming Academy
# 1095134           Dubai Marina  Sports City Swimming Academy
# 176960            Dubai Marina  Sports City Swimming Academy
# 380696            Dubai Marina  Sports City Swimming Academy
# 938960            Dubai Marina  Sports City Swimming Academy
# 985876            Dubai Marina  Sports City Swimming Academy
# 270332            Dubai Marina  Sports City Swimming Academy
# 854383            Dubai Marina  Sports City Swimming Academy
# 494749            Dubai Marina  Sports City Swimming Academy
# 247422            Dubai Marina  Sports City Swimming Academy
# 315149   Jumeirah Lakes Towers                  Burj Al Arab
# 349253   Jumeirah Lakes Towers                  Burj Al Arab
# 357613   Jumeirah Lakes Towers                  Burj Al Arab
# 781013   Jumeirah Lakes Towers                  Burj Al Arab
# 548005   Jumeirah Lakes Towers                  Burj Al Arab
# 386588   Jumeirah Lakes Towers                  Burj Al Arab
# 736520   Jumeirah Lakes Towers                  Burj Al Arab
# 201808   Jumeirah Lakes Towers                  Burj Al Arab
# 379564   Jumeirah Lakes Towers                  Burj Al Arab
#
#                   nearest_metro_en nearest_mall_en rooms_en  has_parking
# 547865    Jumeirah Beach Residency     Marina Mall    2 B/R            1  \
# 399216    Jumeirah Beach Residency     Marina Mall    3 B/R            1
# 620008    Jumeirah Beach Residency     Marina Mall    2 B/R            1
# 470785    Jumeirah Beach Residency     Marina Mall    2 B/R            1
# 252430    Jumeirah Beach Residency     Marina Mall    2 B/R            1
# 405017    Jumeirah Beach Residency     Marina Mall    2 B/R            1
# 850020    Jumeirah Beach Residency     Marina Mall    1 B/R            1
# 35347     Jumeirah Beach Residency     Marina Mall    2 B/R            1
# 232381    Jumeirah Beach Residency     Marina Mall    2 B/R            1
# 196285    Jumeirah Beach Residency     Marina Mall    2 B/R            1
# 39744     Jumeirah Beach Residency     Marina Mall    2 B/R            1
# 122903    Jumeirah Beach Residency     Marina Mall    2 B/R            1
# 436568    Jumeirah Beach Residency     Marina Mall    2 B/R            1
# 167616    Jumeirah Beach Residency     Marina Mall    2 B/R            1
# 228538    Jumeirah Beach Residency     Marina Mall    3 B/R            1
# 577284    Jumeirah Beach Residency     Marina Mall    2 B/R            1
# 9742      Jumeirah Beach Residency     Marina Mall    1 B/R            1
# 835637    Jumeirah Beach Residency     Marina Mall    1 B/R            1
# 883995    Jumeirah Beach Residency     Marina Mall    3 B/R            1
# 727712    Jumeirah Beach Residency     Marina Mall    2 B/R            1
# 366846    Jumeirah Beach Residency     Marina Mall    1 B/R            1
# 901960    Jumeirah Beach Residency     Marina Mall    2 B/R            1
# 851118    Jumeirah Beach Residency     Marina Mall    2 B/R            1
# 439815    Jumeirah Beach Residency     Marina Mall    2 B/R            1
# 623378    Jumeirah Beach Residency     Marina Mall    2 B/R            1
# 885535    Jumeirah Beach Residency     Marina Mall    1 B/R            1
# 1119658   Jumeirah Beach Residency     Marina Mall    1 B/R            1
# 749867    Jumeirah Beach Residency     Marina Mall    2 B/R            1
# 920998    Jumeirah Beach Residency     Marina Mall    2 B/R            1
# 192680    Jumeirah Beach Residency     Marina Mall    2 B/R            1
# 501206    Jumeirah Beach Residency     Marina Mall    2 B/R            1
# 498071    Jumeirah Beach Residency     Marina Mall    2 B/R            1
# 1095134   Jumeirah Beach Residency     Marina Mall    1 B/R            1
# 176960    Jumeirah Beach Residency     Marina Mall    1 B/R            1
# 380696    Jumeirah Beach Residency     Marina Mall    1 B/R            1
# 938960    Jumeirah Beach Residency     Marina Mall    2 B/R            1
# 985876    Jumeirah Beach Residency     Marina Mall    1 B/R            1
# 270332    Jumeirah Beach Residency     Marina Mall    1 B/R            1
# 854383    Jumeirah Beach Residency     Marina Mall    3 B/R            1
# 494749    Jumeirah Beach Residency     Marina Mall    1 B/R            1
# 247422    Jumeirah Beach Residency     Marina Mall    1 B/R            1
# 315149            Damac Properties     Marina Mall    2 B/R            1
# 349253   Marina Mall Metro Station     Marina Mall   Studio            1
# 357613            Damac Properties     Marina Mall    2 B/R            1
# 781013            Damac Properties     Marina Mall    1 B/R            1
# 548005   Marina Mall Metro Station     Marina Mall   Studio            1
# 386588   Marina Mall Metro Station     Marina Mall    2 B/R            1
# 736520            Damac Properties     Marina Mall   Studio            1
# 201808            Damac Properties     Marina Mall    2 B/R            1
# 379564   Marina Mall Metro Station     Marina Mall    1 B/R            1
#
#          procedure_area  ...  building_name_freq proj_freq  master_proj_freq
# 547865           130.99  ...                   1         1                 1  \
# 399216           199.00  ...                   2         2                 2
# 620008           138.98  ...                   3         3                 3
# 470785           146.04  ...                   4         4                 4
# 252430           125.98  ...                   5         5                 5
# 405017           141.03  ...                   6         6                 6
# 850020            95.04  ...                   7         7                 7
# 35347            138.98  ...                   7         7                 7
# 232381           138.98  ...                   7         7                 7
# 196285           130.99  ...                   7         7                 7
# 39744            138.98  ...                   7         7                 7
# 122903           130.99  ...                   7         7                 7
# 436568           141.03  ...                   7         7                 7
# 167616           141.03  ...                   7         7                 7
# 228538           248.98  ...                   8         8                 8
# 577284           145.02  ...                   9         9                 9
# 9742             113.99  ...                  10        10                10
# 835637           113.99  ...                  10        10                10
# 883995           254.00  ...                  11        11                11
# 727712           141.96  ...                  12        12                12
# 366846            95.04  ...                  12        12                12
# 901960           138.98  ...                  12        12                12
# 851118           141.96  ...                  12        12                12
# 439815           124.49  ...                  13        13                13
# 623378           114.46  ...                  14        14                14
# 885535            95.04  ...                  14        14                14
# 1119658           95.04  ...                  14        14                14
# 749867           133.97  ...                  15        15                15
# 920998           125.98  ...                  15        15                15
# 192680           128.02  ...                  16        16                16
# 501206           141.96  ...                  16        16                16
# 498071           128.02  ...                  16        16                16
# 1095134           86.03  ...                  17        17                17
# 176960            75.99  ...                  18        18                18
# 380696           113.99  ...                  18        18                18
# 938960           130.99  ...                  18        18                18
# 985876            95.04  ...                  18        18                18
# 270332            75.99  ...                  18        18                18
# 854383           254.00  ...                  18        18                18
# 494749            95.04  ...                  18        18                18
# 247422            95.04  ...                  18        18                18
# 315149           109.96  ...                   1         1                 1
# 349253            43.45  ...                   1         1                 2
# 357613           109.96  ...                   1         1                 2
# 781013            85.97  ...                   2         2                 3
# 548005            50.57  ...                   2         2                 4
# 386588           128.88  ...                   3         3                 5
# 736520            44.98  ...                   3         3                 6
# 201808           109.96  ...                   3         3                 6
# 379564            76.12  ...                   4         4                 7
#
#          total_building_area  total_areaname_area  total_project_area
# 547865                130.99               130.99              130.99  \
# 399216                329.99               329.99              329.99
# 620008                468.97               468.97              468.97
# 470785                615.01               615.01              615.01
# 252430                740.99               740.99              740.99
# 405017                882.02               882.02              882.02
# 850020                977.06               977.06              977.06
# 35347                 977.06               977.06              977.06
# 232381                977.06               977.06              977.06
# 196285                977.06               977.06              977.06
# 39744                 977.06               977.06              977.06
# 122903                977.06               977.06              977.06
# 436568                977.06               977.06              977.06
# 167616                977.06               977.06              977.06
# 228538               1226.04              1226.04             1226.04
# 577284               1371.06              1371.06             1371.06
# 9742                 1485.05              1485.05             1485.05
# 835637               1485.05              1485.05             1485.05
# 883995               1739.05              1739.05             1739.05
# 727712               1881.01              1881.01             1881.01
# 366846               1881.01              1881.01             1881.01
# 901960               1881.01              1881.01             1881.01
# 851118               1881.01              1881.01             1881.01
# 439815               2005.50              2005.50             2005.50
# 623378               2119.96              2119.96             2119.96
# 885535               2119.96              2119.96             2119.96
# 1119658              2119.96              2119.96             2119.96
# 749867               2253.93              2253.93             2253.93
# 920998               2253.93              2253.93             2253.93
# 192680               2381.95              2381.95             2381.95
# 501206               2381.95              2381.95             2381.95
# 498071               2381.95              2381.95             2381.95
# 1095134              2467.98              2467.98             2467.98
# 176960               2543.97              2543.97             2543.97
# 380696               2543.97              2543.97             2543.97
# 938960               2543.97              2543.97             2543.97
# 985876               2543.97              2543.97             2543.97
# 270332               2543.97              2543.97             2543.97
# 854383               2543.97              2543.97             2543.97
# 494749               2543.97              2543.97             2543.97
# 247422               2543.97              2543.97             2543.97
# 315149                109.96               109.96              109.96
# 349253                 43.45               153.41               43.45
# 357613                109.96               153.41              109.96
# 781013                195.93               239.38              195.93
# 548005                 94.02               289.95               94.02
# 386588                222.90               418.83              222.90
# 736520                240.91               463.81              240.91
# 201808                240.91               463.81              240.91
# 379564                299.02               539.93              299.02
#
#          total_master_project_area  nearest_metro_en_freq
# 547865                      130.99                      1  \
# 399216                      329.99                      2
# 620008                      468.97                      3
# 470785                      615.01                      4
# 252430                      740.99                      5
# 405017                      882.02                      6
# 850020                      977.06                      7
# 35347                       977.06                      7
# 232381                      977.06                      7
# 196285                      977.06                      7
# 39744                       977.06                      7
# 122903                      977.06                      7
# 436568                      977.06                      7
# 167616                      977.06                      7
# 228538                     1226.04                      8
# 577284                     1371.06                      9
# 9742                       1485.05                     10
# 835637                     1485.05                     10
# 883995                     1739.05                     11
# 727712                     1881.01                     12
# 366846                     1881.01                     12
# 901960                     1881.01                     12
# 851118                     1881.01                     12
# 439815                     2005.50                     13
# 623378                     2119.96                     14
# 885535                     2119.96                     14
# 1119658                    2119.96                     14
# 749867                     2253.93                     15
# 920998                     2253.93                     15
# 192680                     2381.95                     16
# 501206                     2381.95                     16
# 498071                     2381.95                     16
# 1095134                    2467.98                     17
# 176960                     2543.97                     18
# 380696                     2543.97                     18
# 938960                     2543.97                     18
# 985876                     2543.97                     18
# 270332                     2543.97                     18
# 854383                     2543.97                     18
# 494749                     2543.97                     18
# 247422                     2543.97                     18
# 315149                      109.96                      1
# 349253                      153.41                      1
# 357613                      153.41                      1
# 781013                      239.38                      2
# 548005                      289.95                      2
# 386588                      418.83                      3
# 736520                      463.81                      3
# 201808                      463.81                      3
# 379564                      539.93                      4
#
#          nearest_landmark_en_freq  nearest_mall_en_freq
# 547865                          1                     1
# 399216                          2                     2
# 620008                          3                     3
# 470785                          4                     4
# 252430                          5                     5
# 405017                          6                     6
# 850020                          7                     7
# 35347                           7                     7
# 232381                          7                     7
# 196285                          7                     7
# 39744                           7                     7
# 122903                          7                     7
# 436568                          7                     7
# 167616                          7                     7
# 228538                          8                     8
# 577284                          9                     9
# 9742                           10                    10
# 835637                         10                    10
# 883995                         11                    11
# 727712                         12                    12
# 366846                         12                    12
# 901960                         12                    12
# 851118                         12                    12
# 439815                         13                    13
# 623378                         14                    14
# 885535                         14                    14
# 1119658                        14                    14
# 749867                         15                    15
# 920998                         15                    15
# 192680                         16                    16
# 501206                         16                    16
# 498071                         16                    16
# 1095134                        17                    17
# 176960                         18                    18
# 380696                         18                    18
# 938960                         18                    18
# 985876                         18                    18
# 270332                         18                    18
# 854383                         18                    18
# 494749                         18                    18
# 247422                         18                    18
# 315149                          1                    19
# 349253                          2                    20
# 357613                          2                    20
# 781013                          3                    21
# 548005                          4                    22
# 386588                          5                    23
# 736520                          6                    24
# 201808                          6                    24
# 379564                          7                    25
#
# [50 rows x 25 columns]

# %%
df_flat.reset_index().to_csv('/Users/a.evdakimov/dubaistream/df_flat.csv' , index = False)

# %%
########################################## Analytics ######################################################

# %%
df_flat.to_csv('/Users/a.evdakimov/dubaistream/df_flat.csv' , index = False)

# %%
df_flat['nearest_landmark_en'].unique()
# Out:
# array(['Sports City Swimming Academy', 'Burj Al Arab', 'Downtown Dubai',
#        'Burj Khalifa', 'Motor City', 'Expo 2020 Site',
#        'Dubai International Airport', 'IMG World Adventures',
#        'Global Village'], dtype=object)

# %%
df_flat['nearest_mall_en'].unique()
# Out:
# array(['Marina Mall', 'Dubai Mall', 'Mall of the Emirates',
#        'Ibn-e-Battuta Mall', 'City Centre Mirdif'], dtype=object)

# %%
unique_id = df_flat[df_flat['nearest_metro_en'] == 'Jumeirah Beach Residency'].id

# %%
import seaborn as sns

# %%
target_type = 'nearest_landmark_en'
target = 'Burj Al Arab'

unique_id = df_flat[df_flat[target_type] == target].id.unique()

# %%
df_flat.nearest_landmark_en
# Out:
# 547865    Sports City Swimming Academy
# 399216    Sports City Swimming Academy
# 620008    Sports City Swimming Academy
# 470785    Sports City Swimming Academy
# 252430    Sports City Swimming Academy
#                       ...
# 525035    Sports City Swimming Academy
# 524536                    Burj Khalifa
# 793451                  Downtown Dubai
# 842645                    Burj Al Arab
# 630781                    Burj Al Arab
# Name: nearest_landmark_en, Length: 71083, dtype: object

# %%
tmp = df_flat[(df_flat['year'].isin(['2019',
                                     '2020',
                                     '2021', 
                                     '2022', 
                                     '2023'])) & \
        (df_flat['id'].isin(unique_id))
        ].groupby(['year', 'rooms_en']).actual_worth.mean()

tmp = pd.DataFrame(tmp).reset_index()
sns.lineplot(x='year', y='actual_worth', hue='rooms_en', data=tmp)
# Out:
# <Axes: xlabel='year', ylabel='actual_worth'>

# %%
def region_analytics(df, target_type, target):
    
    unique_id = df_flat[df_flat[target_type] == target].id.unique()
    
    tmp = df_flat[(df_flat['year'].isin(['2019',
                                     '2020',
                                     '2021', 
                                     '2022', 
                                     '2023',
                                        '2024'])) & \
        (df_flat['id'].isin(unique_id))
        ].groupby(['year', 'rooms_en']).actual_worth.mean()

    tmp = pd.DataFrame(tmp).reset_index()
    
    return sns.lineplot(x='year', y='actual_worth', hue='rooms_en', data=tmp)

# %%
region_analytics(df = df_flat,
                 target_type = 'nearest_mall_en', 
                 target = 'Marina Mall')
# Out:
# <Axes: xlabel='year', ylabel='actual_worth'>

# %%
tmp = df_flat[(df_flat['year'].isin(['2019', '2020', '2021', '2022', '2024'])) & (df_flat['id'].isin(unique_id))].groupby(['year', 'rooms_en']).actual_worth.mean()

# %%
sns.lineplot(x='year', y='actual_worth', hue='rooms_en', data=tmp)
# Out:
# <Axes: xlabel='year', ylabel='actual_worth'>

# %%
# lr.fit(X_train, Y_train)
# Y_pred = lr.predict(X_test)
# mean_absolute_error(Y_pred, Y_test)
# print('LR_MAE: ',  mean_absolute_error(Y_pred, Y_test))

regressor.fit(X_train, Y_train)
Y_pred = regressor.predict(X_test)
mean_absolute_error(Y_pred, Y_test)
print('DecisionTree_MAE: ',  mean_absolute_error(Y_pred, Y_test),
          'DecisionTree_RMSE: ', root_mean_squared_error(Y_pred, Y_test),
     'Decision_Tree_R2: ', r2_score(Y_pred, Y_test))

xgb.fit(X_train, Y_train)
Y_pred = xgb.predict(X_test)
mean_absolute_error(Y_pred, Y_test)
print('XGB_MAE: ',  mean_absolute_error(Y_pred, Y_test),
     'XGB_RMSE: ', root_mean_squared_error(Y_pred, Y_test),
          'XGB_R2: ', r2_score(Y_pred, Y_test))

# rf.fit(X_train, Y_train)
# Y_pred = rf.predict(X_test)
# mean_absolute_error(Y_pred, Y_test)
# print('RF_MAE: ',  mean_absolute_error(Y_pred, Y_test),
#      'XGB_RMSE: ', root_mean_squared_error(Y_pred, Y_test))
# Out:
# DecisionTree_MAE:  180832.7593101989 DecisionTree_RMSE:  249600.72111019865 Decision_Tree_R2:  0.5514807895240355
# XGB_MAE:  129355.36953158061 XGB_RMSE:  178749.6593763993 XGB_R2:  0.7280936595722528

# %%
def IntervalMAE(y_gt,
                y_pred,
                interval = 0.1):
    err = 0
    
    for gt, pred in zip(y_gt, y_pred):
        
        if gt<pred:
            err += gt-((1 - interval)*pred)
            
        elif gt>pred:
            err += gt-((1 + interval)*pred)
            
        elif gt == pred:
            err+=0
    
    err = err/len(y_gt)
            
    return err

# %%
IntervalMAE(y_gt = Y_test,
           y_pred = Y_pred,
           interval = 0.1)/df_flat_encoded['actual_worth'].min()
# Out:
# 0.08284429224125645

# %%
df_flat_encoded['actual_worth'].min()
# Out:
# 400026.0

# %%
np.abs(-12)
# Out:
# 12

# %%
def IntervalMAE_(y_gt,
                y_pred,
                interval = 0.1):
    
    upper_ci = [(1+interval)*i for i in y_gt]
    lower_ci = [(1-interval)*i for i in y_gt]

    err = 0
    
    for num, pred in enumerate(y_pred):
    
        if pred >= lower_ci[num] and pred <= upper_ci[num]:
            err += 0

            
        elif pred < lower_ci[num] or pred > upper_ci[num]:
            err += np.abs(y_gt[num] - pred)
            
    return err/len(y_pred)

# %%
IntervalMAE_(y_gt = Y_test,
           y_pred = Y_pred,
           interval = 0.1)/df_flat_encoded['actual_worth'].mean()
# Out:
# 0.1139882352750167

# %%
interval = 0.1

upper_ci = [(1+interval)*i for i in Y_test]
lower_ci = [(1-interval)*i for i in Y_test]

dict_ = {
        'upper_ci' : upper_ci, 
        'lower_ci' : lower_ci,
        'pred' : Y_pred,
        'gt' : Y_test
        }

tmp = pd.DataFrame(dict_)

# %%
xx = np.atleast_2d(np.linspace(0, 1000000, 9452)).T

# %%
xx
# Out:
# array([[0.00000000e+00],
#        [1.05808909e+02],
#        [2.11617818e+02],
#        ...,
#        [9.99788382e+05],
#        [9.99894191e+05],
#        [1.00000000e+06]])

# %%
len(xx)
# Out:
# 100

# %%
num = 100

xx = np.linspace(0, num, num)

fig = plt.figure(figsize=(100, 30))

plt.plot(xx, Y_test[:num], "r.", markersize=50, label="GT observations")
plt.plot(xx, Y_pred[:num], "b.", markersize=50, label="PRED observations")

plt.plot(xx, upper_ci[:num], "k-.", markersize=10, label="UPPER")
plt.plot(xx, lower_ci[:num], "k-.", markersize=10, label="PRED observations")

plt.fill_between(xx, lower_ci[:num], upper_ci[:num], alpha=0.4, label='+-{}_interval'.format(num))
    
plt.legend(loc="upper left")
plt.show()
# plt.plot(xx, upper_ci, "k-")
# plt.plot(xx, lower_ci, "k-")

# %%
xx.ravel()
# Out:
# array([ 0.        ,  1.11111111,  2.22222222,  3.33333333,  4.44444444,
#         5.55555556,  6.66666667,  7.77777778,  8.88888889, 10.        ])

# %%
xx
# Out:
# array([ 0.        ,  1.11111111,  2.22222222,  3.33333333,  4.44444444,
#         5.55555556,  6.66666667,  7.77777778,  8.88888889, 10.        ])

# %%
df_flat.columns
# Out:
# Index(['area_name_en', 'building_name_en', 'project_name_en',
#        'master_project_en', 'nearest_landmark_en', 'nearest_metro_en',
#        'nearest_mall_en', 'rooms_en', 'has_parking', 'procedure_area',
#        'actual_worth', 'year', 'id', 'freq', 'area_name_freq',
#        'building_name_freq', 'proj_freq', 'master_proj_freq',
#        'total_building_area', 'total_areaname_area', 'total_project_area',
#        'total_master_project_area', 'nearest_metro_en_freq',
#        'nearest_landmark_en_freq', 'nearest_mall_en_freq'],
#       dtype='object')

# %%
##########################################################################################
######################## Making model without id's of flats ##############################
##########################################################################################

# %%
df = pd.read_csv('/Users/a.evdakimov/Transactions.csv')

df_ = df[
    ['instance_date',
    'procedure_name_en',
   'property_type_en',
   'property_sub_type_en',
   'property_usage_en',
#   'reg_type_en',
   'area_name_en',
   'building_name_en',
#   'project_name_en',
#   'master_project_en',
   'nearest_landmark_en',
   'nearest_metro_en',
   'nearest_mall_en',
   'rooms_en',
   'has_parking',
   'procedure_area',
    'actual_worth',
    'meter_sale_price']
  ]

df_ = df_.dropna()

df_['date'] = df_['instance_date'].apply(lambda x: x[-4:]) + '-' + df_['instance_date'].apply(lambda x: x[3:5]) + df_['instance_date'].apply(lambda x: x[5:7])
df_['year'] = df_['date'].apply(lambda x: x[:-5])

df_['date'] = pd.to_datetime(df_['date'])
df_ = df_.sort_values(by='date')



df_sell = df_[df_['procedure_name_en'] == 'Sell']

df_flat = df_sell[df_sell['property_sub_type_en'] == 'Flat']



df_flat.drop(columns = [
                    'procedure_name_en',
                       'property_sub_type_en',
                       'property_type_en',
                       'instance_date',
                      'property_usage_en',
#                      'reg_type_en',
                      'meter_sale_price'
                    ], inplace = True)


df_flat = df_flat[(df_flat.actual_worth < df_flat.actual_worth.quantile(.80)) \
                                & (df_flat.actual_worth > df_flat.actual_worth.quantile(.10))]


df_flat['area_name_freq'] = 0
df_flat['building_name_freq'] = 0
df_flat['nearest_metro_en_freq'] = 0
df_flat['nearest_mall_en_freq'] = 0
df_flat['nearest_landmark_en_freq'] = 0



building_dict_counter = {k:0 for k in df_flat.building_name_en.unique()}
areas_dict_counter = {k:0 for k in df_flat.area_name_en.unique()}
nearest_landmark_en_dict_counter = {k:0 for k in df_flat.nearest_landmark_en.unique()}
nearest_metro_en_dict_counter = {k:0 for k in df_flat.nearest_metro_en.unique()}
nearest_mall_en_dict_counter = {k:0 for k in df_flat.nearest_mall_en.unique()}


for row in df_flat.iterrows():
    
    areas_dict_counter[row[1]['area_name_en']] += 1
    building_dict_counter[row[1]['building_name_en']] += 1
    nearest_landmark_en_dict_counter[row[1]['nearest_landmark_en']] += 1
    nearest_metro_en_dict_counter[row[1]['nearest_metro_en']] += 1
    nearest_mall_en_dict_counter[row[1]['nearest_mall_en']] += 1


    df_flat.loc[row[0],'area_name_freq'] = areas_dict_counter[row[1]['area_name_en']]
    df_flat.loc[row[0],'building_name_freq'] = building_dict_counter[row[1]['building_name_en']]

    df_flat.loc[row[0],'nearest_metro_en_freq'] = nearest_metro_en_dict_counter[row[1]['nearest_metro_en']]
    df_flat.loc[row[0],'nearest_mall_en_freq'] = nearest_mall_en_dict_counter[row[1]['nearest_mall_en']]
    df_flat.loc[row[0],'nearest_landmark_en_freq'] = nearest_landmark_en_dict_counter[row[1]['nearest_landmark_en']]

    
#df_flat_ = df_flat.drop(columns = ['id'], inplace = False) 

df_flat_train_ = df_flat[df_flat['year'].isin([
                                            '2007', '2008','2009',
                                            '2010','2011','2012','2013','2014','2015','2016',
                                             '2017',
                                             '2018',
                                            '2019',
                                            '2020',
                                            '2021',
                                            '2022'])]

df_flat_test_ = df_flat[df_flat['year'].isin(['2023'])]


df_flat_train = df_flat[df_flat['year'].isin([
                                            '2007', '2008','2009',
                                            '2010','2011','2012','2013','2014','2015','2016',
                                             '2017',
                                             '2018',
                                            '2019',
                                            '2020',
                                            '2021',
                                            '2022'])]

df_flat_test = df_flat[df_flat['year'].isin(['2023'])]


ohe = ['area_name_en',
       'building_name_en',
#       'project_name_en',
#       'master_project_en',
       'nearest_landmark_en',
      'nearest_metro_en',
      'nearest_mall_en',
      'rooms_en',
      'has_parking']
# Out:
# /var/folders/_g/j20bjn4s0h39l0xcv3ph8w280000gq/T/ipykernel_49605/623346436.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_flat.drop(columns = [

# %%
#Instantiate TargetEncode class

te = TargetEncode(categories=ohe)
te.fit(df_flat, df_flat['actual_worth'])

df_flat_encoded = te.transform(df_flat)

# %%
Y_train = df_flat_encoded[df_flat_encoded['year'].isin([
                                            '2022',
                                          '2021',
                                         '2020',
                                         '2019',
                                         '2018',
                                         '2017',
                                         '2016',
                                            '2015','2014','2013','2012','2011','2010',
                                            '2007', '2008','2009',

                                       ]
                                      )]['actual_worth']


X_train = df_flat_encoded[df_flat_encoded['year'].isin([
                                            '2022',
                                          '2021',
                                         '2020',
                                         '2019',
                                         '2018',
                                         '2017',
                                         '2016',
                                            '2015','2014','2013','2012','2011','2010',
                                            '2007', '2008','2009',

                                               ]
                                              )]
                                              
Y_test = df_flat_encoded[df_flat_encoded['year'] == '2023']['actual_worth']
X_test = df_flat_encoded[df_flat_encoded['year'] == '2023']



X_train.drop(columns = ['year','actual_worth','date'], inplace = True)
X_test.drop(columns = ['year','actual_worth','date'], inplace = True)



X_train = normalize(np.array(X_train))
Y_train = np.array(Y_train)

X_test = normalize(np.array(X_test))
Y_test = np.array(Y_test)
# Out:
# /var/folders/_g/j20bjn4s0h39l0xcv3ph8w280000gq/T/ipykernel_49605/1079763012.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.drop(columns = ['year','actual_worth','date'], inplace = True)
# /var/folders/_g/j20bjn4s0h39l0xcv3ph8w280000gq/T/ipykernel_49605/1079763012.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.drop(columns = ['year','actual_worth','date'], inplace = True)

# %%
regressor.fit(X_train, Y_train)
Y_pred = regressor.predict(X_test)
mean_absolute_error(Y_pred, Y_test)
print('DecisionTree_MAE: ',  mean_absolute_error(Y_pred, Y_test),
        'DecisionTree_RMSE: ',  mean_squared_error(Y_pred, Y_test),    
          'DecisionTree_RMSE: ', root_mean_squared_error(Y_pred, Y_test),
     'Decision_Tree_R2: ', r2_score(Y_pred, Y_test))

xgb.fit(X_train, Y_train)
Y_pred = xgb.predict(X_test)

mean_absolute_error(Y_pred, Y_test)
print('XGB_MAE: ',  mean_absolute_error(Y_pred, Y_test),
    'XGB_MSE: ',  mean_squared_error(Y_pred, Y_test),
     'XGB_RMSE: ', root_mean_squared_error(Y_pred, Y_test),
          'XGB_R2: ', r2_score(Y_pred, Y_test))
# Out:
# DecisionTree_MAE:  179813.28002703615 DecisionTree_RMSE:  66284671179.23704 DecisionTree_RMSE:  257458.09596755166 Decision_Tree_R2:  0.6197215474565416
# XGB_MAE:  137289.1185081531 XGB_MSE:  35604184026.86185 XGB_RMSE:  188690.7099643802 XGB_R2:  0.7442822285329034

# %%
IntervalMAE(y_gt = Y_test,
           y_pred = Y_pred,
           interval = 0.05)/df_flat_encoded['actual_worth'].mean()
# Out:
# 0.050283456445630766

# %%
IntervalMAE_(y_gt = Y_test,
           y_pred = Y_pred,
           interval = 0.1)/df_flat_encoded['actual_worth'].mean()
# Out:
# 0.1139882352750167

# %%
1) Make data input: 
    area_name_en,
    building_name_en,
    nearest_landmark_en,
    nearest_metro_en,
    nearest_mall_en,
    rooms_en,
    has_parking,
    procedure_area
    
2) Add by condition
    area_name_freq
    building_name_freq,
    nearest_metro_en_freq,
    nearest_mall_en_freq,
    nearest_landmark_en_freq

3) Make prediction

# %%
def data_preparing(df_flat,
                area_name_en,
                building_name_en,
                nearest_landmark_en,
                nearest_metro_en,
                nearest_mall_en,
                rooms_en,
                has_parking,
                procedure_area
               ):
    
    tmp = df_flat[(df_flat['area_name_en'] == area_name_en) \
                   (df_flat['building_name_en'] == building_name_en) \
                   (df_flat['nearest_landmark_en'] == nearest_landmark_en) \
                   (df_flat['nearest_metro_en'] == nearest_metro_en) \
                   (df_flat['nearest_mall_en'] == nearest_mall_en) \
                   (df_flat['has_parking'] == has_parking)]
    #Instantiate TargetEncode class

    te = TargetEncode(categories=ohe)
    te.fit(df_flat, df_flat['actual_worth'])
    df_flat_encoded = te.transform(df_flat)    
    
    ohe = ['area_name_en',
       'building_name_en',
       'nearest_landmark_en',
      'nearest_metro_en',
      'nearest_mall_en',
      'rooms_en',
      'has_parking']

# %%
pd.DataFrame.from_dict({'area_name_en':[area_name_en],
                   'building_name_en':[building_name_en],
                   'nearest_landmark_en':[nearest_landmark_en],
                   'nearest_metro_en':[nearest_metro_en],
                   'nearest_mall_en':[nearest_mall_en],
                   'has_parking':[has_parking],
                    
                   'rooms_en':[rooms_en],
                   'procedure_area':[procedure_area],
                   })
# Out:
#        area_name_en building_name_en nearest_landmark_en     nearest_metro_en
# 0  Al Thanyah Third      ALNAKHEEL 1        Burj Al Arab  Dubai Internet City  \
#
#   nearest_mall_en  has_parking rooms_en  procedure_area
# 0     Marina Mall            1    2 B/R           100.0

# %%
area_name_en = 'Al Thanyah Third'
building_name_en = 'ALNAKHEEL 1'
nearest_landmark_en = 'Burj Al Arab'
nearest_metro_en = 'Dubai Internet City'
nearest_mall_en = 'Marina Mall'
has_parking = 1

rooms_en = '2 B/R'
procedure_area = 100


ts_max = df_flat[(df_flat['area_name_en'] == area_name_en) & \
                   (df_flat['building_name_en'] == building_name_en) & \
                   (df_flat['nearest_landmark_en'] == nearest_landmark_en) & \
                   (df_flat['nearest_metro_en'] == nearest_metro_en) & \
                   (df_flat['nearest_mall_en'] == nearest_mall_en) & \
                   (df_flat['has_parking'] == has_parking)]['date'].max()


tmp = df_flat[(df_flat['area_name_en'] == area_name_en) & \
                   (df_flat['building_name_en'] == building_name_en) & \
                   (df_flat['nearest_landmark_en'] == nearest_landmark_en) & \
                   (df_flat['nearest_metro_en'] == nearest_metro_en) & \
                   (df_flat['nearest_mall_en'] == nearest_mall_en) & \
                   (df_flat['has_parking'] == has_parking) & \
                   (df_flat['date'] == ts_max)]

tmp['procedure_area'] = procedure_area
tmp['rooms_en'] = rooms_en

tmp['area_name_freq'] += 1
tmp['building_name_freq'] += 1
tmp['nearest_metro_en_freq'] += 1
tmp['nearest_mall_en_freq'] += 1
tmp['nearest_landmark_en_freq'] += 1


te = TargetEncode(categories=ohe)
te.fit(df_flat, df_flat['actual_worth'])

tmp_encoded = te.transform(tmp)

tmp_encoded.drop(columns = ['year','actual_worth','date'], inplace = True)

X = normalize(np.array(tmp_encoded))

xgb.predict(X)
# Out:
# /var/folders/_g/j20bjn4s0h39l0xcv3ph8w280000gq/T/ipykernel_49605/951561872.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp['procedure_area'] = procedure_area
# /var/folders/_g/j20bjn4s0h39l0xcv3ph8w280000gq/T/ipykernel_49605/951561872.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp['rooms_en'] = rooms_en
# /var/folders/_g/j20bjn4s0h39l0xcv3ph8w280000gq/T/ipykernel_49605/951561872.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp['area_name_freq'] += 1
# /var/folders/_g/j20bjn4s0h39l0xcv3ph8w280000gq/T/ipykernel_49605/951561872.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp['building_name_freq'] += 1
# /var/folders/_g/j20bjn4s0h39l0xcv3ph8w280000gq/T/ipykernel_49605/951561872.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp['nearest_metro_en_freq'] += 1
# /var/folders/_g/j20bjn4s0h39l0xcv3ph8w280000gq/T/ipykernel_49605/951561872.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp['nearest_mall_en_freq'] += 1
# /var/folders/_g/j20bjn4s0h39l0xcv3ph8w280000gq/T/ipykernel_49605/951561872.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp['nearest_landmark_en_freq'] += 1
# array([1033704.44], dtype=float32)

# %%
xgb.predict(X)
# Out:
# array([1415805.4], dtype=float32)

# %%
ts_max = df_flat[(df_flat['area_name_en'] == area_name_en) & \
                   (df_flat['building_name_en'] == building_name_en) & \
                   (df_flat['nearest_landmark_en'] == nearest_landmark_en) & \
                   (df_flat['nearest_metro_en'] == nearest_metro_en) & \
                   (df_flat['nearest_mall_en'] == nearest_mall_en) & \
                   (df_flat['has_parking'] == has_parking)]['date'].max()


tmp = df_flat[(df_flat['area_name_en'] == area_name_en) & \
                   (df_flat['building_name_en'] == building_name_en) & \
                   (df_flat['nearest_landmark_en'] == nearest_landmark_en) & \
                   (df_flat['nearest_metro_en'] == nearest_metro_en) & \
                   (df_flat['nearest_mall_en'] == nearest_mall_en) & \
                   (df_flat['has_parking'] == has_parking) & \
                   (df_flat['date'] == ts_max)]

# %%
ts_max
# Out:
# Timestamp('2012-10-02 00:00:00')

# %%
df_flat[(df_flat['area_name_en'] == area_name_en) & \
                   (df_flat['building_name_en'] == building_name_en) & \
                   (df_flat['nearest_landmark_en'] == nearest_landmark_en) & \
                   (df_flat['nearest_metro_en'] == nearest_metro_en) & \
                   (df_flat['nearest_mall_en'] == nearest_mall_en) & \
                   (df_flat['has_parking'] == has_parking) &  (df_flat['date'] == df_flat['date'].max())]
# Out:
# Empty DataFrame
# Columns: [area_name_en, building_name_en, nearest_landmark_en, nearest_metro_en, nearest_mall_en, rooms_en, has_parking, procedure_area, actual_worth, date, year, area_name_freq, building_name_freq, nearest_metro_en_freq, nearest_mall_en_freq, nearest_landmark_en_freq]
# Index: []

# %%
df_flat['date'].max()
# Out:
# Timestamp('2024-02-02 00:00:00')

# %%
df_flat['date'].max().iloc[-1]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[387], line 1
# ----> 1 df_flat['date'].max().iloc[-1]
#
# AttributeError: 'Timestamp' object has no attribute 'iloc'

# %%
df_flat[df_flat['date']==df_flat['date'].max()].iloc[-1]
# Out:
# area_name_en                                          Al Merkadh
# building_name_en                       Wilton Park Residences II
# nearest_landmark_en                               Downtown Dubai
# nearest_metro_en            Buj Khalifa Dubai Mall Metro Station
# nearest_mall_en                                       Dubai Mall
# rooms_en                                                  Studio
# has_parking                                                    1
# procedure_area                                              50.2
# actual_worth                                            594828.0
# date                                         2024-02-02 00:00:00
# year                                                        2024
# area_name_freq                                               868
# building_name_freq                                            20
# nearest_metro_en_freq                                      12036
# nearest_mall_en_freq                                       23368
# nearest_landmark_en_freq                                   18427
# Name: 474035, dtype: object

# %%
ts_max
# Out:
#         area_name_freq  building_name_freq  nearest_metro_en_freq
# 530882            4451                  36                   4206  \
#
#         nearest_mall_en_freq  nearest_landmark_en_freq
# 530882                 31481                     24086

# %%
pd.concat([df1,df2], axis=1

# %%
tmp
# Out:
#         area_name_freq  building_name_freq  nearest_metro_en_freq
# 530882            4451                  36                   4206  \
#
#         nearest_mall_en_freq  nearest_landmark_en_freq
# 530882                 31481                     24086

# %%
tmp + 1
# Out:
#         area_name_freq  building_name_freq  nearest_metro_en_freq
# 530882            4452                  37                   4207  \
#
#         nearest_mall_en_freq  nearest_landmark_en_freq
# 530882                 31482                     24087

# %%
df_flat
# Out:
#                    area_name_en           building_name_en
# 301385         Al Thanyah Third                ALNAKHEEL 1  \
# 889440              Marsa Dubai           MARINA HEIGHTS 1
# 586331         Al Thanyah Third                ALNAKHEEL 4
# 190488         Al Thanyah Third                    ALJAZ 1
# 263344         Al Thanyah Third                  NAKHEEL 2
# ...                         ...                        ...
# 789204             Burj Khalifa  THE DUBAI MALL RESIDENCES
# 732867         Al Hebiah Fourth         Royale Residence 2
# 1052017  Al Barsha South Fourth                ROKANE G 22
# 626499             Business Bay                Waves tower
# 474035               Al Merkadh  Wilton Park Residences II
#
#                   nearest_landmark_en                      nearest_metro_en
# 301385                   Burj Al Arab                   Dubai Internet City  \
# 889440                   Burj Al Arab                         Marina Towers
# 586331                   Burj Al Arab                   Dubai Internet City
# 190488                   Burj Al Arab                   Dubai Internet City
# 263344                   Burj Al Arab                   Dubai Internet City
# ...                               ...                                   ...
# 789204                   Burj Khalifa  Buj Khalifa Dubai Mall Metro Station
# 732867   Sports City Swimming Academy                 Nakheel Metro Station
# 1052017  Sports City Swimming Academy                   Dubai Internet City
# 626499                 Downtown Dubai  Buj Khalifa Dubai Mall Metro Station
# 474035                 Downtown Dubai  Buj Khalifa Dubai Mall Metro Station
#
#               nearest_mall_en rooms_en  has_parking  procedure_area
# 301385            Marina Mall    2 B/R            0          130.82  \
# 889440            Marina Mall    2 B/R            1          120.00
# 586331            Marina Mall    1 B/R            0           91.52
# 190488            Marina Mall    3 B/R            1          192.34
# 263344            Marina Mall    2 B/R            0          150.66
# ...                       ...      ...          ...             ...
# 789204             Dubai Mall   Studio            1           51.17
# 732867            Marina Mall    1 B/R            1           64.21
# 1052017  Mall of the Emirates    2 B/R            1           95.62
# 626499             Dubai Mall    1 B/R            1           77.08
# 474035             Dubai Mall   Studio            1           50.20
#
#          actual_worth       date  year  area_name_freq  building_name_freq
# 301385       551800.0 2007-04-02  2007               1                   1  \
# 889440      1134714.0 2007-05-02  2007               1                   1
# 586331       401800.0 2007-05-02  2007               2                   1
# 190488      1414000.0 2007-05-02  2007               3                   1
# 263344       645800.0 2007-05-02  2007               4                   1
# ...               ...        ...   ...             ...                 ...
# 789204      1750000.0 2024-02-02  2024            9207                 454
# 732867       475000.0 2024-02-02  2024            8763                 103
# 1052017     1031500.0 2024-02-02  2024           11413                  43
# 626499      1550000.0 2024-02-02  2024           10932                 142
# 474035       594828.0 2024-02-02  2024             868                  20
#
#          nearest_metro_en_freq  nearest_mall_en_freq  nearest_landmark_en_freq
# 301385                       1                     1                         1
# 889440                       1                     2                         2
# 586331                       2                     3                         3
# 190488                       3                     4                         4
# 263344                       4                     5                         5
# ...                        ...                   ...                       ...
# 789204                   12034                 23366                      4326
# 732867                   15259                 87971                     47950
# 1052017                  16172                 14241                     47951
# 626499                   12035                 23367                     18426
# 474035                   12036                 23368                     18427
#
# [135668 rows x 16 columns]

# %%
area_name_en
# Out:
# 'Al Thanyah Third'

# %%
xgb.predict([X_test[0]])
# Out:
# array([782169.75], dtype=float32)

# %%
Y_test = df_flat_encoded[df_flat_encoded['year'] == '2023']['actual_worth']
X_test = df_flat_encoded[df_flat_encoded['year'] == '2023']

# %%
import pickle
file_name = "xgb_reg.pkl"

# save
pickle.dump(xgb_model, open(file_name, "wb"))

# load
xgb_model_loaded = pickle.load(open(file_name, "rb"))

# test
ind = 1
test = X_val[ind]
xgb_model_loaded.predict(test)[0] == xgb_model.predict(test)[0]

# %%
import pickle
file_name = "xgb_reg.pkl"

# save
pickle.dump(xgb_model, open(file_name, "wb"))

# load
xgb_model_loaded = pickle.load(open(file_name, "rb"))

# test
ind = 1
test = X_val[ind]
xgb_model_loaded.predict(test)[0] == xgb_model.predict(test)[0]
